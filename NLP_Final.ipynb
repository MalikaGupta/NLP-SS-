# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df = pd.read_table('../../data/labeledTrainDataNLP.tsv')
df.head(10)
# Out:
#         id  sentiment                                             review
# 0   5814_8          1  With all this stuff going down at the moment w...
# 1   2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2   7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3   3630_4          0  It must be assumed that those who praised this...
# 4   9495_8          1  Superbly trashy and wondrously unpretentious 8...
# 5   8196_8          1  I dont know why people think this is such a ba...
# 6   7166_2          0  This movie could have been very good, but come...
# 7  10633_1          0  I watched this video at a friend's house. I'm ...
# 8    319_1          0  A friend of mine bought this film for £1, and ...
# 9  8713_10          1  <br /><br />This movie is full of references. ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5705 entries, 0 to 5704
# Data columns (total 3 columns):
# id           5705 non-null object
# sentiment    5705 non-null int64
# review       5705 non-null object
# dtypes: int64(1), object(2)
# memory usage: 133.8+ KB
# None

# %% [markdown]
# ### 1.CLEANING DATA BY REMOVING PUNCTUATION EXCEPT FULLSTOPS

# %%
import nltk
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def rempunc(text):
    text_nopunc="".join([char for char in text if char not in '!"#$%&\'()*+,-/:;<=>?@[\\]^_`{|}~'])
    return (text_nopunc)

# %%
df['review_clean']=df['review'].apply(lambda x: rempunc(x))
df.head()
# Out:
#        id  sentiment                                             review  \
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  The Classic War of the Worlds by Timothy Hines...
# 2  7759_3          0  The film starts with a manager Nicholas Bell g...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
#
#                                         review_clean
# 0  With all this stuff going down at the moment w...
# 1  The Classic War of the Worlds by Timothy Hines...
# 2  The film starts with a manager Nicholas Bell g...
# 3  It must be assumed that those who praised this...
# 4  Superbly trashy and wondrously unpretentious 8...

# %% [markdown]
# ### 2.SENTENCE TOKENIZING AND SAVING SENTENCES IN SEPERATE JSON FILE

# %%
from nltk import sent_tokenize

# %%
def div2sent(text):
    sent_text=sent_tokenize(text)
    return (sent_text)

# %%
df['review_sent']=df['review_clean'].apply(lambda x: div2sent(x))
df.head()
# Out:
#        id  sentiment                                             review  \
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  The Classic War of the Worlds by Timothy Hines...
# 2  7759_3          0  The film starts with a manager Nicholas Bell g...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
#
#                                         review_clean  \
# 0  With all this stuff going down at the moment w...
# 1  The Classic War of the Worlds by Timothy Hines...
# 2  The film starts with a manager Nicholas Bell g...
# 3  It must be assumed that those who praised this...
# 4  Superbly trashy and wondrously unpretentious 8...
#
#                                          review_sent
# 0  [With all this stuff going down at the moment ...
# 1  [The Classic War of the Worlds by Timothy Hine...
# 2  [The film starts with a manager Nicholas Bell ...
# 3  [It must be assumed that those who praised thi...
# 4  [Superbly trashy and wondrously unpretentious ...

# %%
data_sentences=df['review_sent'].loc[0:10]
data_sentences.to_json('SENTENCES.json')

# %% [markdown]
# ### 3.WORD TOKENIZING AND SAVING NOUNS IN SEPERATE JSON FILE

# %%
from nltk import word_tokenize

# %%
def div2word(text):
    word_text=nltk.word_tokenize(str(text))
    return (word_text)

# %%
is_noun = lambda pos: pos[:2] == 'NN'

# %%
def findnouns(text):
    word_text=div2word(text)
    nouns = [word for (word, pos) in nltk.pos_tag(word_text) if is_noun(pos)]
    return (nouns)

# %%
data_nouns=df['review_sent'].loc[0:10].apply(lambda x: findnouns(x))
data_nouns.to_json('NOUNS.json')

# %% [markdown]
# ### 4.SAVING VERBS IN A SEPERATE FILE

# %%
is_verb = lambda pos: pos[:2] == 'VB'

# %%
def findverbs(text):
    word_text=div2word(text)
    verbs = [word for (word, pos) in nltk.pos_tag(word_text) if is_verb(pos)]
    return (verbs)

# %%
data_verbs=df['review_sent'].loc[0:10].apply(lambda x: findverbs(x))
data_verbs.to_json('VERBS.json')

# %% [markdown]
# ### 5. REMOVING STOPWORDS AND SAVING ADJECTIVES IN A SEPERATE JSON FILE

# %%
import re

def tokenize(text):
    tokens = re.split('\W+', text)
    return tokens

df['review_tokenized'] = df['review_clean'].apply(lambda x: tokenize(x))

stopwords= nltk.corpus.stopwords.words('english')

def rmvstpwrds(text):
    text_without_stopwords= [word for word in text if word not in stopwords]
    return (text_without_stopwords)

# %%
df['review_without_stopwords']=df['review_tokenized'].apply(lambda x: rmvstpwrds(x))
df.head(10)
# Out:
#         id  sentiment                                             review  \
# 0   5814_8          1  With all this stuff going down at the moment w...
# 1   2381_9          1  The Classic War of the Worlds by Timothy Hines...
# 2   7759_3          0  The film starts with a manager Nicholas Bell g...
# 3   3630_4          0  It must be assumed that those who praised this...
# 4   9495_8          1  Superbly trashy and wondrously unpretentious 8...
# 5   8196_8          1  I dont know why people think this is such a ba...
# 6   7166_2          0  This movie could have been very good but comes...
# 7  10633_1          0  I watched this video at a friends house. Im gl...
# 8    319_1          0  A friend of mine bought this film for £1 and e...
# 9  8713_10          1  br br This movie is full of references. Like M...
#
#                                         review_clean  \
# 0  With all this stuff going down at the moment w...
# 1  The Classic War of the Worlds by Timothy Hines...
# 2  The film starts with a manager Nicholas Bell g...
# 3  It must be assumed that those who praised this...
# 4  Superbly trashy and wondrously unpretentious 8...
# 5  I dont know why people think this is such a ba...
# 6  This movie could have been very good but comes...
# 7  I watched this video at a friends house. Im gl...
# 8  A friend of mine bought this film for £1 and e...
# 9  br br This movie is full of references. Like M...
#
#                                          review_sent  \
# 0  [With all this stuff going down at the moment ...
# 1  [The Classic War of the Worlds by Timothy Hine...
# 2  [The film starts with a manager Nicholas Bell ...
# 3  [It must be assumed that those who praised thi...
# 4  [Superbly trashy and wondrously unpretentious ...
# 5  [I dont know why people think this is such a b...
# 6  [This movie could have been very good but come...
# 7  [I watched this video at a friends house., Im ...
# 8  [A friend of mine bought this film for £1 and ...
# 9  [br br This movie is full of references., Like...
#
#                             review_without_stopwords  \
# 0  [With, stuff, going, moment, MJ, ive, started,...
# 1  [The, Classic, War, Worlds, Timothy, Hines, en...
# 2  [The, film, starts, manager, Nicholas, Bell, g...
# 3  [It, must, assumed, praised, film, greatest, f...
# 4  [Superbly, trashy, wondrously, unpretentious, ...
# 5  [I, dont, know, people, think, bad, movie, Its...
# 6  [This, movie, could, good, comes, way, short, ...
# 7  [I, watched, video, friends, house, Im, glad, ...
# 8  [A, friend, mine, bought, film, 1, even, gross...
# 9  [br, br, This, movie, full, references, Like, ...
#
#                                     review_tokenized
# 0  [With, all, this, stuff, going, down, at, the,...
# 1  [The, Classic, War, of, the, Worlds, by, Timot...
# 2  [The, film, starts, with, a, manager, Nicholas...
# 3  [It, must, be, assumed, that, those, who, prai...
# 4  [Superbly, trashy, and, wondrously, unpretenti...
# 5  [I, dont, know, why, people, think, this, is, ...
# 6  [This, movie, could, have, been, very, good, b...
# 7  [I, watched, this, video, at, a, friends, hous...
# 8  [A, friend, of, mine, bought, this, film, for,...
# 9  [br, br, This, movie, is, full, of, references...

# %%
is_adjec = lambda pos: pos == 'JJ'
def findadjecs(text):
    word_text=div2word(text)
    adjecs = [word for (word, pos) in nltk.pos_tag(word_text) if is_adjec(pos)]
    return (adjecs)

# %%
data_adjectives=df['review_without_stopwords'].loc[0:100].apply(lambda x: findadjecs(x))
data_adjectives.to_json('ADJECTIVES.json')

# %% [markdown]
# ### 6.STEMMING AND SAVING IN A SEPERATE JSON FILE

# %%
PS=nltk.PorterStemmer()

def stem_text(text):
    stemmedtext=[PS.stem(word) for word in text]
    return stemmedtext

# %%
data_stemmed=df['review_tokenized'].loc[0:100].apply(lambda x: stem_text(x))
data_stemmed.to_json('STEMMED_WORDS.json')

# %% [markdown]
# ### 7.LEMMATIZING AND SAVING IN A SEPERATE JSON FILE

# %%
wnl=nltk.WordNetLemmatizer()

def lemma_text(text):
    lemmatizedtext=[wnl.lemmatize(word) for word in text]
    return lemmatizedtext

# %%
data_lemma=df['review_tokenized'].loc[0:100].apply(lambda x: lemma_text(x))
data_lemma.to_json('LEMMATIZED_WORDS.json')

# %%
df['review_LEMMATIZED']=df['review_tokenized'].apply(lambda x: lemma_text(x))

# %%
df['review_STEMMED']=df['review_tokenized'].apply(lambda x: stem_text(x))
df.head()
# Out:
#        id  sentiment                                             review  \
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  The Classic War of the Worlds by Timothy Hines...
# 2  7759_3          0  The film starts with a manager Nicholas Bell g...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
#
#                                         review_clean  \
# 0  With all this stuff going down at the moment w...
# 1  The Classic War of the Worlds by Timothy Hines...
# 2  The film starts with a manager Nicholas Bell g...
# 3  It must be assumed that those who praised this...
# 4  Superbly trashy and wondrously unpretentious 8...
#
#                                          review_sent  \
# 0  [With all this stuff going down at the moment ...
# 1  [The Classic War of the Worlds by Timothy Hine...
# 2  [The film starts with a manager Nicholas Bell ...
# 3  [It must be assumed that those who praised thi...
# 4  [Superbly trashy and wondrously unpretentious ...
#
#                             review_without_stopwords  \
# 0  [With, stuff, going, moment, MJ, ive, started,...
# 1  [The, Classic, War, Worlds, Timothy, Hines, en...
# 2  [The, film, starts, manager, Nicholas, Bell, g...
# 3  [It, must, assumed, praised, film, greatest, f...
# 4  [Superbly, trashy, wondrously, unpretentious, ...
#
#                                     review_tokenized  \
# 0  [With, all, this, stuff, going, down, at, the,...
# 1  [The, Classic, War, of, the, Worlds, by, Timot...
# 2  [The, film, starts, with, a, manager, Nicholas...
# 3  [It, must, be, assumed, that, those, who, prai...
# 4  [Superbly, trashy, and, wondrously, unpretenti...
#
#                                    review_LEMMATIZED  \
# 0  [With, all, this, stuff, going, down, at, the,...
# 1  [The, Classic, War, of, the, Worlds, by, Timot...
# 2  [The, film, start, with, a, manager, Nicholas,...
# 3  [It, must, be, assumed, that, those, who, prai...
# 4  [Superbly, trashy, and, wondrously, unpretenti...
#
#                                       review_STEMMED
# 0  [with, all, thi, stuff, go, down, at, the, mom...
# 1  [the, classic, war, of, the, world, by, timoth...
# 2  [the, film, start, with, a, manag, nichola, be...
# 3  [It, must, be, assum, that, those, who, prais,...
# 4  [superbl, trashi, and, wondrous, unpretenti, 8...

# %% [markdown]
# ### 8. SUMMARIZING EACH REVIEW AND SAVING IN A SEPERATE JSON FILE

# %%
pip install summa
# Out:
# Requirement already satisfied: summa in /Users/malikagupta/anaconda3/lib/python3.7/site-packages (1.2.0)
# Requirement already satisfied: scipy>=0.19 in /Users/malikagupta/anaconda3/lib/python3.7/site-packages (from summa) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from summa.summarizer import summarize

# %%
df['review_summary']=df['review_clean'].apply(lambda x: summarize(x))

# %%
data_summary=df['review_summary'].loc[0:100]
data_summary.to_json('REVIEW_SUMMARY.json')

# %%
df.head()
# Out:
#        id  sentiment                                             review  \
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  The Classic War of the Worlds by Timothy Hines...
# 2  7759_3          0  The film starts with a manager Nicholas Bell g...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
#
#                                         review_clean  \
# 0  With all this stuff going down at the moment w...
# 1  The Classic War of the Worlds by Timothy Hines...
# 2  The film starts with a manager Nicholas Bell g...
# 3  It must be assumed that those who praised this...
# 4  Superbly trashy and wondrously unpretentious 8...
#
#                                          review_sent  \
# 0  [With all this stuff going down at the moment ...
# 1  [The Classic War of the Worlds by Timothy Hine...
# 2  [The film starts with a manager Nicholas Bell ...
# 3  [It must be assumed that those who praised thi...
# 4  [Superbly trashy and wondrously unpretentious ...
#
#                             review_without_stopwords  \
# 0  [With, stuff, going, moment, MJ, ive, started,...
# 1  [The, Classic, War, Worlds, Timothy, Hines, en...
# 2  [The, film, starts, manager, Nicholas, Bell, g...
# 3  [It, must, assumed, praised, film, greatest, f...
# 4  [Superbly, trashy, wondrously, unpretentious, ...
#
#                                     review_tokenized  \
# 0  [With, all, this, stuff, going, down, at, the,...
# 1  [The, Classic, War, of, the, Worlds, by, Timot...
# 2  [The, film, starts, with, a, manager, Nicholas...
# 3  [It, must, be, assumed, that, those, who, prai...
# 4  [Superbly, trashy, and, wondrously, unpretenti...
#
#                                    review_LEMMATIZED  \
# 0  [With, all, this, stuff, going, down, at, the,...
# 1  [The, Classic, War, of, the, Worlds, by, Timot...
# 2  [The, film, start, with, a, manager, Nicholas,...
# 3  [It, must, be, assumed, that, those, who, prai...
# 4  [Superbly, trashy, and, wondrously, unpretenti...
#
#                                       review_STEMMED  \
# 0  [with, all, thi, stuff, go, down, at, the, mom...
# 1  [the, classic, war, of, the, world, by, timoth...
# 2  [the, film, start, with, a, manag, nichola, be...
# 3  [It, must, be, assum, that, those, who, prais,...
# 4  [superbl, trashi, and, wondrous, unpretenti, 8...
#
#                                       review_summary
# 0  Some of it has subtle messages about MJs feeli...
# 1  We enjoyed the effort Mr. Hines put into being...
# 2  A secret project mutating a primal animal usin...
# 3
# 4  Superbly trashy and wondrously unpretentious 8...
